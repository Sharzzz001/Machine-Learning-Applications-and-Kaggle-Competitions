# %%
from autogluon.tabular import TabularDataset, TabularPredictor
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

train.shape, test.shape
# Out:
# ((1460, 81), (1459, 80))

# %%
# Remove the Ids from train and test, as they are unique for each row and hence not useful for the model
train_ID = train['Id']
test_ID = test['Id']
train.drop(['Id'], axis=1, inplace=True)
test.drop(['Id'], axis=1, inplace=True)
train.shape, test.shape
# Out:
# ((1460, 80), (1459, 79))

# %%
# Split features and labels
train_labels = train['SalePrice'].reset_index(drop=True)
train_features = train.drop(['SalePrice'], axis=1)
test_features = test

# Combine train and test features in order to apply the feature transformation pipeline to the entire dataset
all_features = pd.concat([train_features, test_features]).reset_index(drop=True)
all_features.shape
# Out:
# (2919, 79)

# %%
# determine the threshold for missing values
def percent_missing(df):
    data = pd.DataFrame(df)
    df_cols = list(pd.DataFrame(data))
    dict_x = {}
    for i in range(0, len(df_cols)):
        dict_x.update({df_cols[i]: round(data[df_cols[i]].isnull().mean()*100,2)})
    
    return dict_x

missing = percent_missing(all_features)
df_miss = sorted(missing.items(), key=lambda x: x[1], reverse=True)
print('Percent of missing data')
df_miss[0:10]
# Out:
# Percent of missing data
# [('PoolQC', 99.66),
#  ('MiscFeature', 96.4),
#  ('Alley', 93.22),
#  ('Fence', 80.44),
#  ('MasVnrType', 60.5),
#  ('FireplaceQu', 48.65),
#  ('LotFrontage', 16.65),
#  ('GarageYrBlt', 5.45),
#  ('GarageFinish', 5.45),
#  ('GarageQual', 5.45)]

# %%
all_features['MSSubClass'] = all_features['MSSubClass'].apply(str)
all_features['YrSold'] = all_features['YrSold'].astype(str)
all_features['MoSold'] = all_features['MoSold'].astype(str)

# %%
def handle_missing(features):
    # the data description states that NA refers to typical ('Typ') values
    features['Functional'] = features['Functional'].fillna('Typ')
    # Replace the missing values in each of the columns below with their mode
    features['Electrical'] = features['Electrical'].fillna("SBrkr")
    features['KitchenQual'] = features['KitchenQual'].fillna("TA")
    features['Exterior1st'] = features['Exterior1st'].fillna(features['Exterior1st'].mode()[0])
    features['Exterior2nd'] = features['Exterior2nd'].fillna(features['Exterior2nd'].mode()[0])
    features['SaleType'] = features['SaleType'].fillna(features['SaleType'].mode()[0])
    features['MSZoning'] = features.groupby('MSSubClass')['MSZoning'].transform(lambda x: x.fillna(x.mode()[0]))
    
    # the data description stats that NA refers to "No Pool"
    features["PoolQC"] = features["PoolQC"].fillna("None")
    # Replacing the missing values with 0, since no garage = no cars in garage
    for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'):
        features[col] = features[col].fillna(0)
    # Replacing the missing values with None
    for col in ['GarageType', 'GarageFinish', 'GarageQual', 'GarageCond']:
        features[col] = features[col].fillna('None')
    # NaN values for these categorical basement features, means there's no basement
    for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
        features[col] = features[col].fillna('None')
        
    # Group the by neighborhoods, and fill in missing value by the median LotFrontage of the neighborhood
    features['LotFrontage'] = features.groupby('Neighborhood')['LotFrontage'].transform(lambda x: x.fillna(x.median()))

    # We have no particular intuition around how to fill in the rest of the categorical features
    # So we replace their missing values with None
    objects = []
    for i in features.columns:
        if features[i].dtype == object:
            objects.append(i)
    features.update(features[objects].fillna('None'))
        
    # And we do the same thing for numerical features, but this time with 0s
    numeric_dtypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    numeric = []
    for i in features.columns:
        if features[i].dtype in numeric_dtypes:
            numeric.append(i)
    features.update(features[numeric].fillna(0))    
    return features

all_features = handle_missing(all_features)

# %%
# Let's make sure we handled all the missing values
missing = percent_missing(all_features)
df_miss = sorted(missing.items(), key=lambda x: x[1], reverse=True)
print('Percent of missing data')
df_miss[0:10]
# Out:
# Percent of missing data
# [('MSSubClass', 0.0),
#  ('MSZoning', 0.0),
#  ('LotFrontage', 0.0),
#  ('LotArea', 0.0),
#  ('Street', 0.0),
#  ('Alley', 0.0),
#  ('LotShape', 0.0),
#  ('LandContour', 0.0),
#  ('Utilities', 0.0),
#  ('LotConfig', 0.0)]

# %%
all_features['BsmtFinType1_Unf'] = 1*(all_features['BsmtFinType1'] == 'Unf')
all_features['HasWoodDeck'] = (all_features['WoodDeckSF'] == 0) * 1
all_features['HasOpenPorch'] = (all_features['OpenPorchSF'] == 0) * 1
all_features['HasEnclosedPorch'] = (all_features['EnclosedPorch'] == 0) * 1
all_features['Has3SsnPorch'] = (all_features['3SsnPorch'] == 0) * 1
all_features['HasScreenPorch'] = (all_features['ScreenPorch'] == 0) * 1
all_features['YearsSinceRemodel'] = all_features['YrSold'].astype(int) - all_features['YearRemodAdd'].astype(int)
all_features['Total_Home_Quality'] = all_features['OverallQual'] + all_features['OverallCond']
all_features = all_features.drop(['Utilities', 'Street', 'PoolQC',], axis=1)
all_features['TotalSF'] = all_features['TotalBsmtSF'] + all_features['1stFlrSF'] + all_features['2ndFlrSF']
all_features['YrBltAndRemod'] = all_features['YearBuilt'] + all_features['YearRemodAdd']

all_features['Total_sqr_footage'] = (all_features['BsmtFinSF1'] + all_features['BsmtFinSF2'] +
                                 all_features['1stFlrSF'] + all_features['2ndFlrSF'])
all_features['Total_Bathrooms'] = (all_features['FullBath'] + (0.5 * all_features['HalfBath']) +
                               all_features['BsmtFullBath'] + (0.5 * all_features['BsmtHalfBath']))
all_features['Total_porch_sf'] = (all_features['OpenPorchSF'] + all_features['3SsnPorch'] +
                              all_features['EnclosedPorch'] + all_features['ScreenPorch'] +
                              all_features['WoodDeckSF'])
all_features['TotalBsmtSF'] = all_features['TotalBsmtSF'].apply(lambda x: np.exp(6) if x <= 0.0 else x)
all_features['2ndFlrSF'] = all_features['2ndFlrSF'].apply(lambda x: np.exp(6.5) if x <= 0.0 else x)
all_features['GarageArea'] = all_features['GarageArea'].apply(lambda x: np.exp(6) if x <= 0.0 else x)
all_features['GarageCars'] = all_features['GarageCars'].apply(lambda x: 0 if x <= 0.0 else x)
all_features['LotFrontage'] = all_features['LotFrontage'].apply(lambda x: np.exp(4.2) if x <= 0.0 else x)
all_features['MasVnrArea'] = all_features['MasVnrArea'].apply(lambda x: np.exp(4) if x <= 0.0 else x)
all_features['BsmtFinSF1'] = all_features['BsmtFinSF1'].apply(lambda x: np.exp(6.5) if x <= 0.0 else x)

all_features['haspool'] = all_features['PoolArea'].apply(lambda x: 1 if x > 0 else 0)
all_features['has2ndfloor'] = all_features['2ndFlrSF'].apply(lambda x: 1 if x > 0 else 0)
all_features['hasgarage'] = all_features['GarageArea'].apply(lambda x: 1 if x > 0 else 0)
all_features['hasbsmt'] = all_features['TotalBsmtSF'].apply(lambda x: 1 if x > 0 else 0)
all_features['hasfireplace'] = all_features['Fireplaces'].apply(lambda x: 1 if x > 0 else 0)

# %%
X = all_features.iloc[:len(train_labels), :]
X_test = all_features.iloc[len(train_labels):, :]
X.shape, train_labels.shape, X_test.shape
# Out:
# ((1460, 94), (1460,), (1459, 94))

# %%
X['SalePrice']  = train_labels
# Out:
# C:\Users\shara\AppData\Local\Temp\ipykernel_30516\1603675643.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['SalePrice']  = train_labels

# %%
train = X
test = X_test

# %%
train_data = TabularDataset(train)
test_data = TabularDataset(test)

predictor = TabularPredictor(problem_type='regression',label='SalePrice',eval_metric='root_mean_squared_error').fit(train_data=train_data,presets='best_quality',ag_args_fit={'num_gpus': 1})
predictions = predictor.predict(test_data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20240125_104208"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# Dynamic stacking is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# Detecting stacked overfitting by sub-fitting AutoGluon on the input data. That is, copies of AutoGluon will be sub-fit on subset(s) of the data. Then, the holdout validation data is used to detect stacked overfitting.
# Sub-fit(s) time limit is: 3600 seconds.
# Starting holdout-based sub-fit for dynamic stacking. Context path is: AutogluonModels\ag-20240125_104208/ds_sub_fit/sub_fit_ho.
# Beginning AutoGluon training ... Time limit = 900s
# AutoGluon will save models to "AutogluonModels\ag-20240125_104208/ds_sub_fit/sub_fit_ho"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.10.8
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22621
# CPU Count:          16
# Memory Avail:       5.33 GB / 15.71 GB (34.0%)
# Disk Space Avail:   283.17 GB / 931.50 GB (30.4%)
# ===================================================
# Train Data Rows:    1297
# Train Data Columns: 94
# Label Column:       SalePrice
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5466.86 MB
# 	Train Data (Original)  Memory Usage: 3.69 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 9 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 3): ['has2ndfloor', 'hasgarage', 'hasbsmt']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 15 | ['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', ...]
# 		('int', [])    : 33 | ['LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', ...]
# 		('object', []) : 43 | ['MSSubClass', 'MSZoning', 'Alley', 'LotShape', 'LandContour', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 42 | ['MSSubClass', 'MSZoning', 'Alley', 'LotShape', 'LandContour', ...]
# 		('float', [])     : 15 | ['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', ...]
# 		('int', [])       : 25 | ['LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', ...]
# 		('int', ['bool']) :  9 | ['CentralAir', 'BsmtFinType1_Unf', 'HasWoodDeck', 'HasOpenPorch', 'HasEnclosedPorch', ...]
# 	0.2s = Fit runtime
# 	91 features in original data used to generate 91 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.47 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.24s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 599.69s of the 899.75s of remaining time.
# 	-43776.3353	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 595.08s of the 895.14s of remaining time.
# 	-43374.6874	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 595.01s of the 895.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.40%)
# 	-24653.0096	 = Validation score   (-root_mean_squared_error)
# 	124.58s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 458.34s of the 758.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.57%)
# 	-26142.1946	 = Validation score   (-root_mean_squared_error)
# 	45.94s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 409.63s of the 709.69s of remaining time.
# 	-27656.032	 = Validation score   (-root_mean_squared_error)
# 	2.66s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 406.82s of the 706.88s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=1.02%)
# 	-26875.2937	 = Validation score   (-root_mean_squared_error)
# 	237.28s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 166.88s of the 466.94s of remaining time.
# 	-28471.6643	 = Validation score   (-root_mean_squared_error)
# 	1.39s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 165.3s of the 465.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.19%)
# 	-28192.7883	 = Validation score   (-root_mean_squared_error)
# 	65.34s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 97.25s of the 397.32s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=1.88%)
# 	-29155.7395	 = Validation score   (-root_mean_squared_error)
# 	38.8s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 54.45s of the 354.51s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.13%)
# 	-27148.0816	 = Validation score   (-root_mean_squared_error)
# 	73.85s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 277.8s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.598, 'NeuralNetTorch_BAG_L1': 0.227, 'LightGBM_BAG_L1': 0.103, 'NeuralNetFastAI_BAG_L1': 0.052, 'CatBoost_BAG_L1': 0.021}
# 	-24079.7401	 = Validation score   (-root_mean_squared_error)
# 	0.13s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 277.65s of the 277.61s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.93%)
# 	-26820.5604	 = Validation score   (-root_mean_squared_error)
# 	41.12s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 233.86s of the 233.82s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.80%)
# 	-26825.6411	 = Validation score   (-root_mean_squared_error)
# 	43.07s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 188.12s of the 188.08s of remaining time.
# 	-25564.3163	 = Validation score   (-root_mean_squared_error)
# 	3.48s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 184.49s of the 184.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=1.45%)
# 	-26144.8892	 = Validation score   (-root_mean_squared_error)
# 	174.5s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 7.04s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.569, 'NeuralNetTorch_BAG_L1': 0.2, 'RandomForestMSE_BAG_L2': 0.108, 'LightGBM_BAG_L1': 0.077, 'NeuralNetFastAI_BAG_L1': 0.031, 'CatBoost_BAG_L1': 0.015}
# 	-24062.6966	 = Validation score   (-root_mean_squared_error)
# 	0.19s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 893.18s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240125_104208/ds_sub_fit/sub_fit_ho")
# Leaderboard on holdout data from dynamic stacking:
#                      model  holdout_score     score_val              eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0   RandomForestMSE_BAG_L2  -25936.212499 -25564.316262  root_mean_squared_error        2.954693       1.491872  593.333176                 0.139906                0.095617           3.481873            2       True         14
# 1           XGBoost_BAG_L1  -27464.862812 -29155.739518  root_mean_squared_error        0.691491       0.108078   38.800411                 0.691491                0.108078          38.800411            1       True          9
# 2          CatBoost_BAG_L2  -29019.233749 -26144.889194  root_mean_squared_error        2.901992       1.497100  764.355102                 0.087205                0.100846         174.503800            2       True         15
# 3   NeuralNetFastAI_BAG_L1  -29524.057187 -28192.788303  root_mean_squared_error        0.662460       0.156917   65.335503                 0.662460                0.156917          65.335503            1       True          8
# 4   RandomForestMSE_BAG_L1  -29886.936985 -27656.032001  root_mean_squared_error        0.142290       0.096884    2.660097                 0.142290                0.096884           2.660097            1       True          5
# 5      WeightedEnsemble_L3  -30199.006304 -24062.696640  root_mean_squared_error        2.962235       1.491872  593.525263                 0.007542                0.000000           0.192087            3       True         16
# 6     ExtraTreesMSE_BAG_L1  -30514.130837 -28471.664284  root_mean_squared_error        0.101967       0.130168    1.390075                 0.101967                0.130168           1.390075            1       True          7
# 7        LightGBMXT_BAG_L1  -30565.537475 -24653.009642  root_mean_squared_error        0.373201       0.267311  124.581783                 0.373201                0.267311         124.581783            1       True          3
# 8          CatBoost_BAG_L1  -30721.404087 -26875.293725  root_mean_squared_error        0.129325       0.115378  237.278477                 0.129325                0.115378         237.278477            1       True          6
# 9      WeightedEnsemble_L2  -30794.856644 -24079.740097  root_mean_squared_error        1.825648       0.823837  547.118783                 0.008089                0.000000           0.132571            2       True         11
# 10         LightGBM_BAG_L2  -32523.997690 -26825.641060  root_mean_squared_error        3.019083       1.467924  632.922602                 0.204296                0.071669          43.071300            2       True         13
# 11         LightGBM_BAG_L1  -32829.399212 -26142.194588  root_mean_squared_error        0.210415       0.079509   45.941260                 0.210415                0.079509          45.941260            1       True          4
# 12       LightGBMXT_BAG_L2  -33965.780247 -26820.560440  root_mean_squared_error        3.016589       1.473719  630.970358                 0.201802                0.077465          41.119056            2       True         12
# 13   NeuralNetTorch_BAG_L1  -34663.140296 -27148.081620  root_mean_squared_error        0.442159       0.204722   73.849189                 0.442159                0.204722          73.849189            1       True         10
# 14   KNeighborsDist_BAG_L1  -51178.972838 -43374.687422  root_mean_squared_error        0.034858       0.030128    0.008508                 0.034858                0.030128           0.008508            1       True          2
# 15   KNeighborsUnif_BAG_L1  -51615.623588 -43776.335305  root_mean_squared_error        0.026621       0.207160    0.006000                 0.026621                0.207160           0.006000            1       True          1
# Stacked overfitting occurred: False.
# Spend 898 seconds for the sub-fit(s) during dynamic stacking.
# Time left for full fit of AutoGluon: 2702 seconds.
# Starting full fit now with num_stack_levels 1.
# Beginning AutoGluon training ... Time limit = 2702s
# AutoGluon will save models to "AutogluonModels\ag-20240125_104208"
# =================== System Info ===================
# AutoGluon Version:  1.0.0
# Python Version:     3.10.8
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22621
# CPU Count:          16
# Memory Avail:       2.95 GB / 15.71 GB (18.8%)
# Disk Space Avail:   283.17 GB / 931.50 GB (30.4%)
# ===================================================
# Train Data Rows:    1460
# Train Data Columns: 94
# Label Column:       SalePrice
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    3021.87 MB
# 	Train Data (Original)  Memory Usage: 4.16 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 9 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 3): ['has2ndfloor', 'hasgarage', 'hasbsmt']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 15 | ['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', ...]
# 		('int', [])    : 33 | ['LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', ...]
# 		('object', []) : 43 | ['MSSubClass', 'MSZoning', 'Alley', 'LotShape', 'LandContour', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])  : 42 | ['MSSubClass', 'MSZoning', 'Alley', 'LotShape', 'LandContour', ...]
# 		('float', [])     : 15 | ['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', ...]
# 		('int', [])       : 25 | ['LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', ...]
# 		('int', ['bool']) :  9 | ['CentralAir', 'BsmtFinType1_Unf', 'HasWoodDeck', 'HasOpenPorch', 'HasEnclosedPorch', ...]
# 	0.2s = Fit runtime
# 	91 features in original data used to generate 91 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.53 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.23s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 108 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 1800.73s of the 2701.76s of remaining time.
# 	-44333.9727	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 1800.66s of the 2701.69s of remaining time.
# 	-44102.5868	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1800.59s of the 2701.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.66%)
# 	-24396.8295	 = Validation score   (-root_mean_squared_error)
# 	139.88s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1658.05s of the 2559.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.77%)
# 	-26857.3778	 = Validation score   (-root_mean_squared_error)
# 	44.99s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 1610.42s of the 2511.45s of remaining time.
# 	-27903.4398	 = Validation score   (-root_mean_squared_error)
# 	2.86s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1607.35s of the 2508.38s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=1.47%)
# 	-27344.1988	 = Validation score   (-root_mean_squared_error)
# 	324.6s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 1280.11s of the 2181.15s of remaining time.
# 	-27894.3756	 = Validation score   (-root_mean_squared_error)
# 	1.68s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1278.22s of the 2179.26s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.22%)
# 	-32133.1916	 = Validation score   (-root_mean_squared_error)
# 	58.72s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1216.82s of the 2117.85s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=1.73%)
# 	-25811.6654	 = Validation score   (-root_mean_squared_error)
# 	51.87s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1162.31s of the 2063.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.13%)
# 	-26497.8932	 = Validation score   (-root_mean_squared_error)
# 	90.18s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1069.49s of the 1970.52s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=3.50%)
# 	-27316.2114	 = Validation score   (-root_mean_squared_error)
# 	309.05s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 757.64s of the 1658.67s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=1.28%)
# 	-27122.4786	 = Validation score   (-root_mean_squared_error)
# 	103.69s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 651.27s of the 1552.3s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.12%)
# 	-28658.0221	 = Validation score   (-root_mean_squared_error)
# 	106.57s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 541.97s of the 1443.0s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=1.65%)
# 	-25414.7232	 = Validation score   (-root_mean_squared_error)
# 	133.24s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 405.9s of the 1306.93s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.24%)
# 	-30742.2399	 = Validation score   (-root_mean_squared_error)
# 	67.71s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 335.43s of the 1236.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=6.60%)
# 	-26055.2665	 = Validation score   (-root_mean_squared_error)
# 	94.08s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 238.52s of the 1139.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.36%)
# 	-25408.4653	 = Validation score   (-root_mean_squared_error)
# 	128.58s	 = Training   runtime
# 	0.48s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 106.94s of the 1007.97s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.10%)
# 	-28167.2569	 = Validation score   (-root_mean_squared_error)
# 	87.8s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 16.31s of the 917.34s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=9.84%)
# 	-27710.2674	 = Validation score   (-root_mean_squared_error)
# 	32.97s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 881.42s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.395, 'NeuralNetTorch_BAG_L1': 0.171, 'XGBoost_BAG_L1': 0.132, 'NeuralNetTorch_r79_BAG_L1': 0.118, 'LightGBM_r131_BAG_L1': 0.105, 'CatBoost_r9_BAG_L1': 0.053, 'NeuralNetTorch_r22_BAG_L1': 0.026}
# 	-23386.5322	 = Validation score   (-root_mean_squared_error)
# 	0.27s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 881.13s of the 881.06s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.76%)
# 	-25357.8948	 = Validation score   (-root_mean_squared_error)
# 	50.03s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 828.2s of the 828.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.72%)
# 	-25702.8562	 = Validation score   (-root_mean_squared_error)
# 	131.1s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 693.93s of the 693.85s of remaining time.
# 	-25200.945	 = Validation score   (-root_mean_squared_error)
# 	5.33s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 688.43s of the 688.36s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=1.39%)
# 	-25654.2395	 = Validation score   (-root_mean_squared_error)
# 	199.18s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 486.47s of the 486.4s of remaining time.
# 	-24813.1469	 = Validation score   (-root_mean_squared_error)
# 	2.36s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 483.91s of the 483.84s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.23%)
# 	-29835.8253	 = Validation score   (-root_mean_squared_error)
# 	63.2s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 417.81s of the 417.73s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=1.77%)
# 	-26038.0422	 = Validation score   (-root_mean_squared_error)
# 	36.68s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 378.29s of the 378.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.13%)
# 	-26570.5844	 = Validation score   (-root_mean_squared_error)
# 	85.45s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 289.87s of the 289.8s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=3.42%)
# 	-27877.5554	 = Validation score   (-root_mean_squared_error)
# 	173.06s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L2 ... Training model for up to 113.99s of the 113.92s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=1.48%)
# 	-24698.0277	 = Validation score   (-root_mean_squared_error)
# 	58.58s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L2 ... Training model for up to 52.66s of the 52.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (1.0 workers, per: cpus=1, gpus=1, memory=0.13%)
# 	-28726.3459	 = Validation score   (-root_mean_squared_error)
# 	74.1s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -24.86s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.36, 'NeuralNetTorch_BAG_L1': 0.15, 'XGBoost_BAG_L2': 0.12, 'XGBoost_BAG_L1': 0.11, 'NeuralNetTorch_r79_BAG_L1': 0.11, 'LightGBM_r131_BAG_L1': 0.09, 'CatBoost_r9_BAG_L1': 0.05, 'CatBoost_r177_BAG_L2': 0.01}
# 	-23342.5715	 = Validation score   (-root_mean_squared_error)
# 	0.36s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2727.25s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20240125_104208")

# %%
predictor.leaderboard()
# Out:
#                           model     score_val              eval_metric  \
# 0           WeightedEnsemble_L3 -23342.571494  root_mean_squared_error
# 1           WeightedEnsemble_L2 -23386.532191  root_mean_squared_error
# 2             LightGBMXT_BAG_L1 -24396.829530  root_mean_squared_error
# 3          CatBoost_r177_BAG_L2 -24698.027731  root_mean_squared_error
# 4          ExtraTreesMSE_BAG_L2 -24813.146947  root_mean_squared_error
# 5        RandomForestMSE_BAG_L2 -25200.944990  root_mean_squared_error
# 6             LightGBMXT_BAG_L2 -25357.894820  root_mean_squared_error
# 7           LightGBM_r96_BAG_L1 -25408.465335  root_mean_squared_error
# 8          LightGBM_r131_BAG_L1 -25414.723190  root_mean_squared_error
# 9               CatBoost_BAG_L2 -25654.239534  root_mean_squared_error
# 10              LightGBM_BAG_L2 -25702.856223  root_mean_squared_error
# 11               XGBoost_BAG_L1 -25811.665363  root_mean_squared_error
# 12               XGBoost_BAG_L2 -26038.042216  root_mean_squared_error
# 13           CatBoost_r9_BAG_L1 -26055.266455  root_mean_squared_error
# 14        NeuralNetTorch_BAG_L1 -26497.893171  root_mean_squared_error
# 15        NeuralNetTorch_BAG_L2 -26570.584374  root_mean_squared_error
# 16              LightGBM_BAG_L1 -26857.377839  root_mean_squared_error
# 17         CatBoost_r177_BAG_L1 -27122.478589  root_mean_squared_error
# 18         LightGBMLarge_BAG_L1 -27316.211419  root_mean_squared_error
# 19              CatBoost_BAG_L1 -27344.198804  root_mean_squared_error
# 20           XGBoost_r33_BAG_L1 -27710.267389  root_mean_squared_error
# 21         LightGBMLarge_BAG_L2 -27877.555438  root_mean_squared_error
# 22         ExtraTreesMSE_BAG_L1 -27894.375555  root_mean_squared_error
# 23       RandomForestMSE_BAG_L1 -27903.439810  root_mean_squared_error
# 24    NeuralNetTorch_r22_BAG_L1 -28167.256892  root_mean_squared_error
# 25    NeuralNetTorch_r79_BAG_L1 -28658.022106  root_mean_squared_error
# 26    NeuralNetTorch_r79_BAG_L2 -28726.345880  root_mean_squared_error
# 27       NeuralNetFastAI_BAG_L2 -29835.825343  root_mean_squared_error
# 28  NeuralNetFastAI_r191_BAG_L1 -30742.239883  root_mean_squared_error
# 29       NeuralNetFastAI_BAG_L1 -32133.191593  root_mean_squared_error
# 30        KNeighborsDist_BAG_L1 -44102.586769  root_mean_squared_error
# 31        KNeighborsUnif_BAG_L1 -44333.972659  root_mean_squared_error
#
#     pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  \
# 0        3.552047  1874.114027                0.000000           0.362286
# 1        1.454133   703.907203                0.000000           0.272308
# 2        0.304716   139.879596                0.304716         139.879596
# 3        3.447877  1837.075881                0.109620          58.576889
# 4        3.478032  1780.856945                0.139775           2.357953
# 5        3.452935  1783.828722                0.114678           5.329730
# 6        3.437097  1828.533023                0.098840          50.034031
# 7        0.484254   128.581746                0.484254         128.581746
# 8        0.246869   133.243357                0.246869         133.243357
# 9        3.458683  1977.682697                0.120426         199.183705
# 10       3.603816  1909.599069                0.265559         131.100077
# 11       0.143606    51.868907                0.143606          51.868907
# 12       3.442426  1815.174852                0.104169          36.675860
# 13       0.146219    94.084918                0.146219          94.084918
# 14       0.197038    90.184601                0.197038          90.184601
# 15       3.600645  1863.952247                0.262388          85.453255
# 16       0.077981    44.988270                0.077981          44.988270
# 17       0.107243   103.692637                0.107243         103.692637
# 18       0.331655   309.048849                0.331655         309.048849
# 19       0.112881   324.597500                0.112881         324.597500
# 20       0.121606    32.971647                0.121606          32.971647
# 21       3.480344  1951.563887                0.142087         173.064895
# 22       0.138362     1.676037                0.138362           1.676037
# 23       0.143247     2.860069                0.143247           2.860069
# 24       0.206743    87.799999                0.206743          87.799999
# 25       0.208942   106.573516                0.208942         106.573516
# 26       3.591371  1852.595464                0.253114          74.096472
# 27       3.485175  1841.698805                0.146918          63.199813
# 28       0.147970    67.712602                0.147970          67.712602
# 29       0.140260    58.723829                0.140260          58.723829
# 30       0.034591     0.005375                0.034591           0.005375
# 31       0.044075     0.005537                0.044075           0.005537
#
#     stack_level  can_infer  fit_order
# 0             3       True         32
# 1             2       True         20
# 2             1       True          3
# 3             2       True         30
# 4             2       True         25
# 5             2       True         23
# 6             2       True         21
# 7             1       True         17
# 8             1       True         14
# 9             2       True         24
# 10            2       True         22
# 11            1       True          9
# 12            2       True         27
# 13            1       True         16
# 14            1       True         10
# 15            2       True         28
# 16            1       True          4
# 17            1       True         12
# 18            1       True         11
# 19            1       True          6
# 20            1       True         19
# 21            2       True         29
# 22            1       True          7
# 23            1       True          5
# 24            1       True         18
# 25            1       True         13
# 26            2       True         31
# 27            2       True         26
# 28            1       True         15
# 29            1       True          8
# 30            1       True          2
# 31            1       True          1

# %%
y_pred = predictor.predict(test_data)
y_pred
# Out:
# 1460    128013.148438
# 1461    163463.421875
# 1462    186566.390625
# 1463    196924.671875
# 1464    185932.578125
#             ...
# 2914     84197.039062
# 2915     83918.992188
# 2916    164384.843750
# 2917    116865.382812
# 2918    215166.390625
# Name: SalePrice, Length: 1459, dtype: float32

# %%
sample = pd.read_csv('sample_submission.csv')
sample.head()
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977

# %%
type(y_pred)
# Out:
# pandas.core.series.Series

# %%
submission = pd.DataFrame({'Id':sample['Id'],'SalePrice':y_pred.tolist()})
submission.to_csv('samp_autoG.csv',index=False)
submission.head()
# Out:
#      Id      SalePrice
# 0  1461  128013.148438
# 1  1462  163463.421875
# 2  1463  186566.390625
# 3  1464  196924.671875
# 4  1465  185932.578125
